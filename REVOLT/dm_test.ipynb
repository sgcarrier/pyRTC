# %%
#!/usr/bin/python

import sys
import os
import time
import struct


from Lib64.asdk import DM
# os.chdir("/home/revoltuser/ALPAO/Linux/Samples/Python3/")
print(os.getcwd())
dm = DM( "alpaoHSDM277-15-005" )
# Out:
# /home/revoltuser/pyRTC/REVOLT
